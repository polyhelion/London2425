# %% [markdown]
# # Spark prototyping quickstart

# %%
# !apt-get install openjdk-17-jdk-headless -qq > /dev/null
# !wget -q https://dlcdn.apache.org/spark/spark-3.5.7/spark-3.5.7-bin-hadoop3.tgz
# !tar xf spark-3.5.7-bin-hadoop3.tgz
# %pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
# os.environ["SPARK_HOME"] = "/opt/spark-3.5.7-bin-hadoop3"
os.environ["SPARK_HOME"] = "/content/spark-3.5.7-bin-hadoop3"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
import random

import pyspark as ps

import findspark
findspark.init()

spark = ps.sql.SparkSession.builder \
                .master("local") \
                .appName("Proto") \
                .config("spark.executor.memory", "1gb") \
                .getOrCreate()
sc = spark.sparkContext

# do stuff

spark.stop()
